# %% [markdown]
# # **Mock Exam Business Lab and Professional Skills: Python Module**

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected.
#
# Remove the line that states 'raise NotImplementedError()" as you start working on an exercise.
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and student id below:

# %%
NAME = ""
STUDENT_ID = ""

# %% [markdown]
# # Part A: Risk simulation
#
# In this assignment, you are tasked with simulating part of the Risk board game.
#
# Risk is a board game of global conquest where 2 to 6 players battle for world domination. Each player is assigned territories and armies, and the objective is to eliminate opponents and control entire continents. Players take turns deploying reinforcements, engaging in battles through dice rolls, and strategically planning their moves. The game combines elements of diplomacy, alliances, and calculated risk-taking. With its iconic world map and varied gameplay dynamics, Risk has remained a popular and enduring classic since its introduction in the 1950s, fostering intense competition and strategic thinking among players.

# %% [markdown]
# ![risk.png](data:image/png;base64,...)

# %% [markdown]
# 1) Create two variables: player1 and player2. Assign your name to player 1, assign the name of a friend to player 2.

# %%
raise NotImplementedError()

# %% [markdown]
# 2) Import the random module

# %%
raise NotImplementedError()

# %% [markdown]
# 3) Simulate rolling a (six-sided) die and print the number that ends on top.

# %%
raise NotImplementedError()

# %% [markdown]
# 4) Roll the dice for player 1 and for player 2.
#
# Utilize print statements with f-strings to to display the name of the winner (the player who rolled highest). If it's a draw, then print that it's draw.

# %%
raise NotImplementedError()

# %% [markdown]
# 5) In Risk, when a player initiates an attack on a territory, the attacker can roll a maximum of three dice, while the defender can roll a maximum of two dice. The number of dice rolled is determined by the number of armies involved in the attack or defense. We assume the attacker always rolls 3 dice, while the defender always rolls 2 dice.
#
# The dice are then compared in pairs, with the highest attacker die facing the highest defender die, and the second-highest attacker die facing the second-highest defender die. The player with the higher result wins, and in the case of a tie, the defender wins. The losing player must then remove one army unit from the territory.
#
# See two examples below:

# %% [markdown]
# ![risk_example.png](data:image/png;base64,...)

# %% [markdown]
# We will now prepare for the Risk game. Create two empty lists, one named 'attacker', the other one named 'defender'.

# %% [markdown]
# 6) We assume that player 1 is the attacker, while player 2 is the defender. Roll the dice 3 times for the attacker, and 2 times for the defender. Add the outcome of rolls to the two lists you created before (3 rolls added to the list of the attacker, and 2 rolls added to th elist of the defender).

# %%
raise NotImplementedError()

# %% [markdown]
# 7) Print the two lists (after 'rolling the dice' in the previous step)

# %%
raise NotImplementedError()

# %% [markdown]
# 8) Run the following code to sort the rolls for each player from high to low.
#
# attacker.sort(reverse=True)
#
# defender.sort(reverse=True)

# %%
attacker.sort(reverse=True)
defender.sort(reverse=True)

# %% [markdown]
# 9) For the 2 highest rolls of each player, print who wins.
#
# Hint: compare the first element of each list for the two players to see who wins for the first comparison (each player's highest roll). Then compare the second element of each list for the two players to see who wins the second comparison (each player's second highest roll).

# %%
raise NotImplementedError()

# %% [markdown]
# 10) Create a function named *play_risk*, based on the steps above, to play the Risk game. Instead of printing who wins, the function should return a value:
#
# -2 if the attacker loses both rolls<br>
# 0 if the attacker wins one roll and loses the other<br>
# 2 if the attacker wins both rolls<br>
#
# The function should not accept any parameters.
#
# Hint: Perform two comparisons (as explained above). The first comparison should set a variable's value to 1 if the attacker wins, and to -1 if the defender wins. You can pick any name for this variable. The second comparison should increase the value by 1 if the attacker wins, and decrease it by 1 if the defender wins.

# %%
"YOUR ANSWER HERE"
raise NotImplementedError()

# %% [markdown]
# 11) Call the function play_risk() to play the game. Check if returned value is indeed -2, 0 or 2.

# %%
raise NotImplementedError()

# %% [markdown]
# 12) Create a simulation function, called *sim_games*, which accepts one parameter *n* for the number of simulations.
#
# The function should play the Risk game *n* times (by calling the function *play_risk()*), and keep track of the scores. After the simulation is completed, the function should return a list of the game outcomes.
#
# Hint: use a list to track the winner of each game. Create an empty list at the beginning of the simulation, and append the outcome of each game to the list (i.e., -2, 0 or 2).

# %%
raise NotImplementedError()

# %% [markdown]
# 13) Run the simulation 20 times and print the outcomes of the games:

# %%
raise NotImplementedError()

# %% [markdown]
# 14) Run the simulation 100,000 times. Assign (save) the outcomes to a variable named *outcomes*.

# %%
raise NotImplementedError()

# %% [markdown]
# 15) Print the average (mean) of all the game outcomes. The mean can be computed as the sum of the list's values divided by the length of the list. A positive outcome implies that the attacker won more often than the defender, while a negative score indicates that the defender won most games.

# %%
raise NotImplementedError()

# %% [markdown]
# # Part B: Credit Approval
#
# This file concerns credit card applications.  All attribute names and values have been changed to meaningless symbols to protect confidentiality of the data.
#
# The dataset contains the following variables:
#
# approval:	Target	Categorical<br>
# A15:	Feature,	Continuous<br>
# A14:	Feature,	Continuous<br>
# A13:	Feature,	Categorical<br>
# A12:	Feature,	Categorical<br>
# A11:	Feature,	Continuous<br>
# A10:	Feature,	Categorical<br>
# A9:	Feature,	Categorical<br>
# A8:	Feature,	Continuous<br>
# A7:	Feature,	Categorical<br>
# A6:	Feature,	Categorical<br>
# A5:	Feature,	Categorical<br>
# A4:	Feature,	Categorical<br>
# A3:	Feature,	Continuous<br>
# A2:	Feature,	Continuous<br>
# A1:	Feature,	Categorical<br>
#
# Source: https://archive.ics.uci.edu/dataset/27/credit+approval

# %% [markdown]
# 1) Load the required modules: pandas, numpy and matplotlib.pyplot

# %%
raise NotImplementedError()

# %% [markdown]
# 2) Read the dataset into a pandas DataFrame:

# %%
df=pd.read_csv('credit_approval.csv')

# %% [markdown]
# 3) Examine the number of missing observations per variable, using the DataFrame command isnull.sum()

# %%
raise NotImplementedError()

# %% [markdown]
# 4) Drop observations with missing values using the DataFrame command .dropna()

# %%
raise NotImplementedError()

# %% [markdown]
# 5) Display the first 10 rows of your DataFrame

# %%
raise NotImplementedError()

# %% [markdown]
# 6) Display the last 10 rows of your DataFrame

# %%
raise NotImplementedError()

# %% [markdown]
# 7) Create a function named 'credit_approved'. The function should accept a parameter with a value of either + or -. The function should return 1 if the value was a +, 0 otherwise.

# %%
"YOUR ANSWER HERE"
raise NotImplementedError()

# %% [markdown]
# 8) Create a new column in your DataFrame with the name 'approved' by applying the 'credit_approved' function to the column 'approval'

# %%
raise NotImplementedError()

# %% [markdown]
# 9) Drop the column 'approval' from the DataFrame by using the drop(columns='approval') command.

# %%
raise NotImplementedError()

# %% [markdown]
# 10) Use the command .value_counts() on the column 'approval' to compute the number of credit approvals that were approved vs those that were denied.

# %%
raise NotImplementedError()

# %% [markdown]
# 11) Create dummy variables from all the categorical variables. You can use the following code:
#
# df=pd.get_dummies(df, drop_first=True)

# %%
df=pd.get_dummies(df, drop_first=True)

# %% [markdown]
# 12) Obtain information about the variables in the dataset using the describe().T command

# %%
raise NotImplementedError()

# %% [markdown]
# 13) Split your DataFrame into two parts:
#
# - *X* which contains all the features (explanatory variables)<br>
# - *y* which is your outcome variable (credit approval).

# %%
raise NotImplementedError()

# %% [markdown]
# 14) Split your X and y datasets into training and test datasets:
#
#   Use 85% of your sample for training and 15% of your sample for testing.
#
#   You can use the train_test_split function from sklearn.model_selection to do this.

# %%
raise NotImplementedError()

# %% [markdown]
# 15) Normalize the columns in your X vectors. Normalization means that you change the range of each variable from 0 to 1.
#
#   You can normalize all values using the following lines of code:
#
#   from sklearn import preprocessing<br>
#   min_max_scaler = preprocessing.MinMaxScaler()<br>
#   X_train = min_max_scaler.fit_transform(X_train)<br>
#   X_test = min_max_scaler.transform(X_test)

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_train = min_max_scaler.fit_transform(X_train)
X_test = min_max_scaler.transform(X_test)

# %% [markdown]
# 16) Use the following machine learning algorithms to predict Credit Approval.
#
#   1. k-Nearest neighbors
#   2. Logistic regression
#   3. Decision tree
#   4. Neural network
#
# For each algorithm save the accuracy, precision and recall scores.

# %% [markdown]
# 16a) K-Nearest Neigbors:
# - Import the k-Nearest neighbors classifier algorithm from scikit-learn.
# - Import *ConfusionMatrixDisplay*, *precision_score* and *recall_score* from sklearn.metrics
# - Create an instance of the model and fit it to the training data
# - Compute: 1) the accuracy of the model on the test data, 2) the precision score for the test data, and 3) the recall score for the test data.
# - Display a confusion matrix
# - Decide on the appropriate 'k' for the the algorithm.
#
# Utilize print statements with f-strings to neatly display the scores..

# %%
raise NotImplementedError()

# %% [markdown]
# 16b) Logistic regression:
# - Import the logistic regression classifier algorithm from scikit-learn.
# - Create an instance of the model and fit it to the training data
# - Compute: 1) the accuracy of the model on the training data, 2) the accuracy of the model on the test data, 3) the precision score for the test data, and 4) the recall score for the test data.
# - Display a confusion matrix
#
# Utilize print statements with f-strings to neatly display the scores.

# %%
raise NotImplementedError()

# %% [markdown]
# 16c) Decision tree:
# - Import the decision tree classifier algorithm from scikit-learn.
# - Create an instance of the model and fit it to the training data
# - Compute: 1) the accuracy of the model on the training data, 2) the accuracy of the model on the test data, 3) the precision score for the test data, and 4) the recall score for the test data.
# - Display a confusion matrix
# - Decide on the appropriate depth of the tree.
#
# Utilize print statements with f-strings to neatly display the scores.

# %%
raise NotImplementedError()

# %% [markdown]
# 16d) Neural network:
# - Import the MLP neural network classifier algorithm from scikit-learn.
# - Create an instance of the model and fit it to the training data
# - Compute: 1) the accuracy of the model on the training data, 2) the accuracy of the model on the test data, 3) the precision score for the test data, and 4) the recall score for the test data.
# - Display a confusion matrix
#
# Utilize print statements with f-strings to neatly display the scores.
#
# Note: you can increase the maximum number of iterations by setting as follows:<br>
# mlp = MLPClassifier(max_iter=2000)

# %%
raise NotImplementedError()

# %% [markdown]
# 17) Discuss the algorithms you used and how you determined the optimal specifications. Which algorithm do you believe performs best?
